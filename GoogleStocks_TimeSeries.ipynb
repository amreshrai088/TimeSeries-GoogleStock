# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas_datareader as pdr
import datetime as dt
ticker = 'GOOG'
start = dt.datetime(2012, 1, 1)
end = dt.datetime(2022, 11, 21)
data = pdr.get_data_yahoo(ticker, start, end)

print(data)
# Out:
#                   High        Low       Open      Close       Volume  \
# Date
# 2012-01-03   16.641375  16.248346  16.262545  16.573130  147611217.0
# 2012-01-04   16.693678  16.453827  16.563665  16.644611  114989399.0
# 2012-01-05   16.537264  16.344486  16.491436  16.413727  131808205.0
# 2012-01-06   16.438385  16.184088  16.417213  16.189817  108119746.0
# 2012-01-09   16.114599  15.472754  16.102144  15.503389  233776981.0
# ...                ...        ...        ...        ...          ...
# 2022-11-15  100.419998  97.019997  98.669998  98.720001   31831000.0
# 2022-11-16   99.849998  97.902000  98.019997  98.989998   24660200.0
# 2022-11-17   99.480003  97.099998  97.180000  98.500000   21818700.0
# 2022-11-18   99.160004  96.739998  99.010002  97.800003   24959300.0
# 2022-11-21   98.720001  95.669998  97.559998  95.830002   18677400.0
#
#             Adj Close
# Date
# 2012-01-03  16.573130
# 2012-01-04  16.644611
# 2012-01-05  16.413727
# 2012-01-06  16.189817
# 2012-01-09  15.503389
# ...               ...
# 2022-11-15  98.720001
# 2022-11-16  98.989998
# 2022-11-17  98.500000
# 2022-11-18  97.800003
# 2022-11-21  95.830002
#
# [2741 rows x 6 columns]

# %%
data.shape
# Out:
# (2741, 6)

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  16.641375  16.248346  16.262545  16.573130  147611217.0  16.573130
# 2012-01-04  16.693678  16.453827  16.563665  16.644611  114989399.0  16.644611
# 2012-01-05  16.537264  16.344486  16.491436  16.413727  131808205.0  16.413727
# 2012-01-06  16.438385  16.184088  16.417213  16.189817  108119746.0  16.189817
# 2012-01-09  16.114599  15.472754  16.102144  15.503389  233776981.0  15.503389

# %%
data.reset_index(inplace=True)

# %%
data.tail()
# Out:
#            Date        High        Low       Open      Close      Volume  \
# 2736 2022-11-15  100.419998  97.019997  98.669998  98.720001  31831000.0
# 2737 2022-11-16   99.849998  97.902000  98.019997  98.989998  24660200.0
# 2738 2022-11-17   99.480003  97.099998  97.180000  98.500000  21818700.0
# 2739 2022-11-18   99.160004  96.739998  99.010002  97.800003  24959300.0
# 2740 2022-11-21   98.720001  95.669998  97.559998  95.830002  18677400.0
#
#       Adj Close
# 2736  98.720001
# 2737  98.989998
# 2738  98.500000
# 2739  97.800003
# 2740  95.830002

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2741 non-null   datetime64[ns]
#  1   High       2741 non-null   float64
#  2   Low        2741 non-null   float64
#  3   Open       2741 non-null   float64
#  4   Close      2741 non-null   float64
#  5   Volume     2741 non-null   float64
#  6   Adj Close  2741 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 150.0 KB

# %%
Yt_data=data[['Date','High']]

# %%
Yt_data.shape
# Out:
# (2741, 2)

# %%
Yt_data.head(10)
# Out:
#         Date       High
# 0 2012-01-03  16.641375
# 1 2012-01-04  16.693678
# 2 2012-01-05  16.537264
# 3 2012-01-06  16.438385
# 4 2012-01-09  16.114599
# 5 2012-01-10  15.785831
# 6 2012-01-11  15.675993
# 7 2012-01-12  15.763166
# 8 2012-01-13  15.615220
# 9 2012-01-17  15.740501

# %%
Yt_data.isnull().sum()
# Out:
# Date    0
# High    0
# dtype: int64

# %%
Yt_data.groupby('Date')['High'].sum().reset_index()
# Out:
#            Date        High
# 0    2012-01-03   16.641375
# 1    2012-01-04   16.693678
# 2    2012-01-05   16.537264
# 3    2012-01-06   16.438385
# 4    2012-01-09   16.114599
# ...         ...         ...
# 2736 2022-11-15  100.419998
# 2737 2022-11-16   99.849998
# 2738 2022-11-17   99.480003
# 2739 2022-11-18   99.160004
# 2740 2022-11-21   98.720001
#
# [2741 rows x 2 columns]

# %%
Yt_data.sort_values(by='Date', inplace=True)
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\3592563674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Yt_data.sort_values(by='Date', inplace=True)

# %%
Yt_data.min()
# Out:
# Date    2012-01-03 00:00:00
# High              14.060299
# dtype: object

# %%
Yt_data.max()
# Out:
# Date    2022-11-21 00:00:00
# High             152.100006
# dtype: object

# %%
52*10
# Out:
# 520

# %%
Yt_data.set_index(['Date'],inplace=True)

# %%
Yt_data1=Yt_data['High'].resample('W').mean()

# %%
Yt_data1.shape
# Out:
# (569,)

# %%
Yt_data1
# Out:
# Date
# 2012-01-08    16.577675
# 2012-01-15    15.790962
# 2012-01-22    15.554012
# 2012-01-29    14.494920
# 2012-02-05    14.610138
#                 ...
# 2022-10-30    99.753999
# 2022-11-06    91.419002
# 2022-11-13    92.149001
# 2022-11-20    99.218001
# 2022-11-27    98.720001
# Freq: W-SUN, Name: High, Length: 569, dtype: float64

# %% [markdown]
# ### Visualization

# %%
Yt_data1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decompose = seasonal_decompose(Yt_data1, model = 'multiplicative', two_sided=False, extrapolate_trend=4)

# %%
decompose.plot()
plt.show()

# %%
pd.DataFrame({'Actual': decompose.observed, 'SI': decompose.seasonal, 'Trend': decompose.trend, 'It':decompose.resid})
# Out:
#                Actual        SI       Trend        It
# Date
# 2012-01-08  16.577675  1.025990   13.132036  1.230406
# 2012-01-15  15.790962  1.020622   13.190030  1.173000
# 2012-01-22  15.554012  1.015690   13.248025  1.155926
# 2012-01-29  14.494920  1.014118   13.306020  1.074185
# 2012-02-05  14.610138  1.025571   13.364014  1.065986
# ...               ...       ...         ...       ...
# 2022-10-30  99.753999  0.990993  126.513069  0.795654
# 2022-11-06  91.419002  0.991851  125.528286  0.734258
# 2022-11-13  92.149001  0.990421  124.425621  0.747758
# 2022-11-20  99.218001  0.998022  123.377476  0.805776
# 2022-11-27  98.720001  0.996627  122.411851  0.809187
#
# [569 rows x 4 columns]

# %% [markdown]
# ### ETS

# %%
train=Yt_data1['2012-01-08':'2020-01-01']
test=Yt_data1['2020-01-01':]

# %%
train.shape
# Out:
# (417,)

# %%
test.shape
# Out:
# (152,)

# %% [markdown]
# ### Loop for Selecting best alpha, beta and gamma to get optimal MAE for ETS method

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

alpha=np.linspace(0,.99,10)
beta=np.linspace(0,.99,10)
gamma=np.linspace(0,.99,10)

# alpha=[0.01, .4, .3, .23]

min_mae=9876543456789
al1=0
bet1=0
gam1=0

for a in alpha:
    for b in beta:
        for g in gamma:
            ets_model = ExponentialSmoothing(train, trend='mul', seasonal='mul', seasonal_periods=12)
            ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
            
            pred_y = ets_fit.forecast(6)
            
            mae = np.mean(abs(test-pred_y)/test)
            print(f'MAE = {mae} for alpha {a}, beta {b}, gamma {g}')
            
            if min_mae > mae:
                min_mae = mae
                al1 = a
                bet1 = b
                gam1 = g
                
mypara={'Alpha' : al1, 'Beta' : bet1, 'Gamma' : gam1}
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 1.0 for alpha 0.0, beta 0.0, gamma 0.0
# MAE = 0.048495374968936224 for alpha 0.0, beta 0.0, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.0, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.0, gamma 0.33
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.0, gamma 0.44
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.0, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.0, gamma 0.66
# MAE = 0.09249241623852976 for alpha 0.0, beta 0.0, gamma 0.77
# MAE = 0.09068529947277466 for alpha 0.0, beta 0.0, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.0, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 1.0 for alpha 0.0, beta 0.11, gamma 0.0
# MAE = 0.048495374968936224 for alpha 0.0, beta 0.11, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.11, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.11, gamma 0.33
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.11, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.11, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.11, gamma 0.66
# MAE = 0.09249241623852976 for alpha 0.0, beta 0.11, gamma 0.77
# MAE = 0.09068529947277466 for alpha 0.0, beta 0.11, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.11, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE = 1.0 for alpha 0.0, beta 0.22, gamma 0.0
# MAE = 0.048495374968936224 for alpha 0.0, beta 0.22, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.22, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.22, gamma 0.33
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.22, gamma 0.44
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.22, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.22, gamma 0.66
# MAE = 0.09249241623852976 for alpha 0.0, beta 0.22, gamma 0.77
# MAE = 0.09068529947277466 for alpha 0.0, beta 0.22, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.22, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.4962093555391826 for alpha 0.0, beta 0.33, gamma 0.0
# MAE = 0.04849540958533416 for alpha 0.0, beta 0.33, gamma 0.11
# MAE = 0.06625901747037319 for alpha 0.0, beta 0.33, gamma 0.22
# MAE = 0.08163959064955588 for alpha 0.0, beta 0.33, gamma 0.33
# MAE = 0.0900347164891549 for alpha 0.0, beta 0.33, gamma 0.44
# MAE = 0.0933227391646988 for alpha 0.0, beta 0.33, gamma 0.55
# MAE = 0.09364046690663352 for alpha 0.0, beta 0.33, gamma 0.66
# MAE = 0.09249244352907432 for alpha 0.0, beta 0.33, gamma 0.77
# MAE = 0.09068813870619623 for alpha 0.0, beta 0.33, gamma 0.88
# MAE = 0.08851881361138335 for alpha 0.0, beta 0.33, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: invalid value encountered in double_scalars
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: invalid value encountered in double_scalars
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = nan for alpha 0.0, beta 0.44, gamma 0.0
# MAE = 0.048495390183698174 for alpha 0.0, beta 0.44, gamma 0.11
# MAE = 0.06625883250011554 for alpha 0.0, beta 0.44, gamma 0.22
# MAE = 0.08163959353375998 for alpha 0.0, beta 0.44, gamma 0.33
# MAE = 0.09003467985280929 for alpha 0.0, beta 0.44, gamma 0.44
# MAE = 0.09332340495726556 for alpha 0.0, beta 0.44, gamma 0.55
# MAE = 0.09364043027815205 for alpha 0.0, beta 0.44, gamma 0.66
# MAE = 0.09249242356102035 for alpha 0.0, beta 0.44, gamma 0.77
# MAE = 0.09068536122945269 for alpha 0.0, beta 0.44, gamma 0.88
# MAE = 0.08851877637237414 for alpha 0.0, beta 0.44, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE = 1.0 for alpha 0.0, beta 0.55, gamma 0.0
# MAE = 0.048495374968936224 for alpha 0.0, beta 0.55, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.55, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.55, gamma 0.33
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.55, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.55, gamma 0.55
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.55, gamma 0.66
# MAE = 0.09249241623852976 for alpha 0.0, beta 0.55, gamma 0.77
# MAE = 0.09068533578239624 for alpha 0.0, beta 0.55, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.55, gamma 0.99
# MAE = 9.801656030835933e+55 for alpha 0.0, beta 0.66, gamma 0.0
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.04849541659778083 for alpha 0.0, beta 0.66, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.66, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.66, gamma 0.33
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.66, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.66, gamma 0.55
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.66, gamma 0.66
# MAE = 0.09249241623852976 for alpha 0.0, beta 0.66, gamma 0.77
# MAE = 0.09068533578239624 for alpha 0.0, beta 0.66, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.66, gamma 0.99
# MAE = 0.3793415323507556 for alpha 0.0, beta 0.77, gamma 0.0
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.048495374968936224 for alpha 0.0, beta 0.77, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.77, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.77, gamma 0.33
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.77, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.77, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.77, gamma 0.66
# MAE = 0.09249244536212008 for alpha 0.0, beta 0.77, gamma 0.77
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09068533578239624 for alpha 0.0, beta 0.77, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.77, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE = 0.735964076509429 for alpha 0.0, beta 0.88, gamma 0.0
# MAE = 0.04849541659778083 for alpha 0.0, beta 0.88, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.88, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.88, gamma 0.33
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.88, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.88, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.88, gamma 0.66
# MAE = 0.09249244536212008 for alpha 0.0, beta 0.88, gamma 0.77
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09068533578239624 for alpha 0.0, beta 0.88, gamma 0.88
# MAE = 0.08851877545225977 for alpha 0.0, beta 0.88, gamma 0.99
# MAE = nan for alpha 0.0, beta 0.99, gamma 0.0
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: invalid value encountered in double_scalars
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: invalid value encountered in double_scalars
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.04849541659778083 for alpha 0.0, beta 0.99, gamma 0.11
# MAE = 0.06625903964791431 for alpha 0.0, beta 0.99, gamma 0.22
# MAE = 0.08163955783321912 for alpha 0.0, beta 0.99, gamma 0.33
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# MAE = 0.09003472229613929 for alpha 0.0, beta 0.99, gamma 0.44
# MAE = 0.09332275875634945 for alpha 0.0, beta 0.99, gamma 0.55
# MAE = 0.09364041666449056 for alpha 0.0, beta 0.99, gamma 0.66
# MAE = 0.09249244536212008 for alpha 0.0, beta 0.99, gamma 0.77
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# ...
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE = 0.9534890108248514 for alpha 0.99, beta 0.88, gamma 0.33
# MAE = 1.7872412183869068e+23 for alpha 0.99, beta 0.88, gamma 0.44
# MAE = 7.936366701638252e+28 for alpha 0.99, beta 0.88, gamma 0.55
# MAE = 2.2813124386339405e+52 for alpha 0.99, beta 0.88, gamma 0.66
# MAE = nan for alpha 0.99, beta 0.88, gamma 0.77
# MAE = 2.0012842576494573e+24 for alpha 0.99, beta 0.88, gamma 0.88
# MAE = nan for alpha 0.99, beta 0.88, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1357: RuntimeWarning: overflow encountered in multiply
#   fitted = trend * s[:-m]
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1357: RuntimeWarning: overflow encountered in multiply
#   fitted = trend * s[:-m]
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# MAE = 0.06565245622772707 for alpha 0.99, beta 0.99, gamma 0.0
# MAE = 0.05503363436584933 for alpha 0.99, beta 0.99, gamma 0.11
# MAE = 0.05821252536491384 for alpha 0.99, beta 0.99, gamma 0.22
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE = 0.9938948242362473 for alpha 0.99, beta 0.99, gamma 0.33
# MAE = 54292025819.05193 for alpha 0.99, beta 0.99, gamma 0.44
# MAE = 406577.14134278527 for alpha 0.99, beta 0.99, gamma 0.55
# MAE = 8.623453700918595e+91 for alpha 0.99, beta 0.99, gamma 0.66
# MAE = 1.040928331485613 for alpha 0.99, beta 0.99, gamma 0.77
# MAE = 1.3517236920975835e+146 for alpha 0.99, beta 0.99, gamma 0.88
# MAE = nan for alpha 0.99, beta 0.99, gamma 0.99
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\810300719.py:18: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=a, smoothing_slope=b, smoothing_seasonal=g)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1338: RuntimeWarning: overflow encountered in multiply
#   alphac * trended(lvls[i - 1], dampen(b[i - 1], phi))
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1344: RuntimeWarning: overflow encountered in multiply
#   s[i + m - 1] = y_gamma[i - 1] / trended(
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1341: RuntimeWarning: invalid value encountered in true_divide
#   b[i] = (beta * detrend(lvls[i], lvls[i - 1])) + (
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1353: RuntimeWarning: overflow encountered in multiply
#   trend = trended(lvls, b)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:1406: RuntimeWarning: overflow encountered in matmul
#   sse = err.T @ err

# %%
min_mae
# Out:
# 0.010247665477164878

# %%
mypara
# Out:
# {'Alpha': 0.22, 'Beta': 0.11, 'Gamma': 0.66}

# %%
alpha=0.22
beta=0.11
gamma=0.66

ets_model = ExponentialSmoothing(train, trend='mul', seasonal='mul', seasonal_periods=12)

ets_fit = ets_model.fit(smoothing_level=alpha, smoothing_slope=beta, smoothing_seasonal=gamma)
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_18808\2088912185.py:7: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   ets_fit = ets_model.fit(smoothing_level=alpha, smoothing_slope=beta, smoothing_seasonal=gamma)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
ets_fit.forecast(12)
# Out:
# 2020-01-05    68.924799
# 2020-01-12    71.152094
# 2020-01-19    72.729764
# 2020-01-26    73.138327
# 2020-02-02    73.948965
# 2020-02-09    73.973136
# 2020-02-16    73.322942
# 2020-02-23    72.911897
# 2020-03-01    73.545926
# 2020-03-08    75.062683
# 2020-03-15    75.530199
# 2020-03-22    74.808598
# Freq: W-SUN, dtype: float64

# %%
ets_fit.forecast(12).plot()
# Out:
# <AxesSubplot:>

# %%
train.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### ARIMA

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# Null - Series is not stationary
# Alternate - Series is stationary
# Decision : if p > 0.05, Series is non stationary 
#            if p <= 0.05 Series is stationary

# %%
adfuller(Yt_data1)
# Out:
# (-1.1041757379477157,
#  0.7134037994443869,
#  17,
#  551,
#  {'1%': -3.442273822587951,
#   '5%': -2.8667997388278583,
#   '10%': -2.5695712667942465},
#  2275.7250438226774)

# %%
print('Result of Dicky-Fuller Test:')
dftest = adfuller(Yt_data1)
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Obsversations Used'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Result of Dicky-Fuller Test:
# Test Statistic                   -1.104176
# p-value                           0.713404
# #lags Used                       17.000000
# Number of Obsversations Used    551.000000
# Critical Value (1%)              -3.442274
# Critical Value (5%)              -2.866800
# Critical Value (10%)             -2.569571
# dtype: float64

# %% [markdown]
# #### The p value is greater than 0.05, Series is not Stationary

# %%
adfuller(Yt_data1.diff(1).dropna())
# Out:
# (-2.8239003762309864,
#  0.05494003777892393,
#  19,
#  548,
#  {'1%': -3.442339408568417,
#   '5%': -2.866828612425054,
#   '10%': -2.5695866531248335},
#  2244.3155582479667)

# %% [markdown]
# #### The p value is greater than 0.05, Series is not Stationary

# %%
adfuller(np.log(Yt_data1))
# Out:
# (-1.2044988373019165,
#  0.6716574376673605,
#  2,
#  566,
#  {'1%': -3.441956369604407,
#   '5%': -2.8666599744723045,
#   '10%': -2.5694967895716014},
#  -2410.7815171918032)

# %%
adfuller(np.log(Yt_data1).diff(2).dropna())
# Out:
# (-4.911255671040462,
#  3.315707860495783e-05,
#  19,
#  547,
#  {'1%': -3.4423614311926514,
#   '5%': -2.866838307535097,
#   '10%': -2.56959181953083},
#  -2372.9590189074815)

# %%
print('Result of Dicky-Fuller Test:')
dftest = adfuller(np.log(Yt_data1).diff(2).dropna())
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Obsversations Used'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Result of Dicky-Fuller Test:
# Test Statistic                   -4.911256
# p-value                           0.000033
# #lags Used                       19.000000
# Number of Obsversations Used    547.000000
# Critical Value (1%)              -3.442361
# Critical Value (5%)              -2.866838
# Critical Value (10%)             -2.569592
# dtype: float64

# %% [markdown]
# #### as my Series is stationary with a diff so my d would be 2

# %%
import statsmodels.tsa.api as smt

fig, axes = plt.subplots(1,2, sharey = False, sharex=False)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(np.log(Yt_data1).diff(2).dropna(), lags=10, ax=axes[0], alpha=0.02)
smt.graphics.plot_pacf(np.log(Yt_data1).diff(2).dropna(), lags=10, ax=axes[1], alpha=0.02, method='ols')
plt.tight_layout()

# %%
# p=2, q=1, d=2
# P=p, Q=q, D=2, period = 12

# %%
import statsmodels.api as sm
# here in function order = (p,d,q)
# seasonal_order = (P,D,Q, period) 

model = sm.tsa.statespace.SARIMAX(train, order = (2,2,1), seasonal_order=(2,2,1,12),
                                enforce_stationary = False,
                                enforce_invertibility = False).fit()

# %%
print(model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               High   No. Observations:                  417
# Model:             SARIMAX(2, 2, 1)x(2, 2, 1, 12)   Log Likelihood                -629.538
# Date:                            Tue, 22 Nov 2022   AIC                           1273.077
# Time:                                    09:14:59   BIC                           1300.858
# Sample:                                01-08-2012   HQIC                          1284.088
#                                      - 12-29-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1328      0.042      3.178      0.001       0.051       0.215
# ar.L2         -0.1812      0.051     -3.557      0.000      -0.281      -0.081
# ma.L1         -1.0000     39.132     -0.026      0.980     -77.697      75.697
# ar.S.L12      -0.6671      0.049    -13.608      0.000      -0.763      -0.571
# ar.S.L24      -0.3049      0.054     -5.602      0.000      -0.412      -0.198
# ma.S.L12      -1.0000    421.453     -0.002      0.998    -827.034     825.034
# sigma2         1.2068    509.600      0.002      0.998    -997.592    1000.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):               119.49
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.25   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecastarima=model.forecast(6)
forecastarima
# Out:
# 2020-01-05    68.778168
# 2020-01-12    68.831618
# 2020-01-19    69.845362
# 2020-01-26    69.119229
# 2020-02-02    69.380926
# 2020-02-09    69.455186
# Freq: W-SUN, Name: predicted_mean, dtype: float64

# %%
test
# Out:
# Date
# 2020-01-05    67.895500
# 2020-01-12    70.733290
# 2020-01-19    72.570000
# 2020-01-26    74.825987
# 2020-02-02    72.869101
#                 ...
# 2022-10-30    99.753999
# 2022-11-06    91.419002
# 2022-11-13    92.149001
# 2022-11-20    99.218001
# 2022-11-27    98.720001
# Freq: W-SUN, Name: High, Length: 152, dtype: float64

# %%
print('MAE', np.mean(abs(test-forecastarima)/test))
# Out:
# MAE 0.04364382301551115

# %%
import itertools

p=[0,1,2,3]
d=[0,1]       
q=[0,1,2,3]
P=[0,1,2]
D=[0]
Q=[0,1,2]

pdq=list(itertools.product(p,d,q))
#Generate all different combinations of seasonal p,q,and d triplets
seasonal_pdq=[(x[0],x[1],x[2],12) for x in list(itertools.product(P,D,Q))]
best_pdq= None
best_results=8673499999999997
best_seasonal_pdq= None
count=0
for i in pdq:
    for j in seasonal_pdq:
        model1= sm.tsa.statespace.SARIMAX(train, order=i, seasonal_order=j,
                                enforce_stationarity= False,
                                enforce_invertibility= False).fit()
        ftest= model1.forecast(6)
        mae=np.mean(abs(test-ftest)/test)
        count+=1
        print(f"Complete for {count}/288 MAE={mae}, pdq={i}, seasonal_pdq={j}")
        if best_results>mae:
            best_results=mae
            best_pdq=i
            best_seasonal_pdq=j
# Out:
# Complete for 1/288 MAE=1.0, pdq=(0, 0, 0), seasonal_pdq=(0, 0, 0, 12)
# Complete for 2/288 MAE=0.5659645419630988, pdq=(0, 0, 0), seasonal_pdq=(0, 0, 1, 12)
# Complete for 3/288 MAE=0.4264650918846164, pdq=(0, 0, 0), seasonal_pdq=(0, 0, 2, 12)
# Complete for 4/288 MAE=0.08830640760276537, pdq=(0, 0, 0), seasonal_pdq=(1, 0, 0, 12)
# Complete for 5/288 MAE=0.09367028062912795, pdq=(0, 0, 0), seasonal_pdq=(1, 0, 1, 12)
# Complete for 6/288 MAE=0.09716307178376392, pdq=(0, 0, 0), seasonal_pdq=(1, 0, 2, 12)
# Complete for 7/288 MAE=0.09791296911260672, pdq=(0, 0, 0), seasonal_pdq=(2, 0, 0, 12)
# Complete for 8/288 MAE=0.09650315795656905, pdq=(0, 0, 0), seasonal_pdq=(2, 0, 1, 12)
# Complete for 9/288 MAE=0.09210628418131432, pdq=(0, 0, 0), seasonal_pdq=(2, 0, 2, 12)
# Complete for 10/288 MAE=0.9208927486455908, pdq=(0, 0, 1), seasonal_pdq=(0, 0, 0, 12)
# Complete for 11/288 MAE=0.5191560184759227, pdq=(0, 0, 1), seasonal_pdq=(0, 0, 1, 12)
# Complete for 12/288 MAE=0.37483986176312517, pdq=(0, 0, 1), seasonal_pdq=(0, 0, 2, 12)
# Complete for 13/288 MAE=0.07996470788450899, pdq=(0, 0, 1), seasonal_pdq=(1, 0, 0, 12)
# Complete for 14/288 MAE=0.08724902963975978, pdq=(0, 0, 1), seasonal_pdq=(1, 0, 1, 12)
# Complete for 15/288 MAE=0.05164377643076551, pdq=(0, 0, 1), seasonal_pdq=(1, 0, 2, 12)
# Complete for 16/288 MAE=0.0906283922010686, pdq=(0, 0, 1), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 17/288 MAE=0.08662577358104324, pdq=(0, 0, 1), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 18/288 MAE=0.08353635401754823, pdq=(0, 0, 1), seasonal_pdq=(2, 0, 2, 12)
# Complete for 19/288 MAE=0.8318701967612748, pdq=(0, 0, 2), seasonal_pdq=(0, 0, 0, 12)
# Complete for 20/288 MAE=0.48588511103561965, pdq=(0, 0, 2), seasonal_pdq=(0, 0, 1, 12)
# Complete for 21/288 MAE=0.33151138524826906, pdq=(0, 0, 2), seasonal_pdq=(0, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 22/288 MAE=0.07979375105105203, pdq=(0, 0, 2), seasonal_pdq=(1, 0, 0, 12)
# Complete for 23/288 MAE=0.07834543287290244, pdq=(0, 0, 2), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 24/288 MAE=0.04987932525529768, pdq=(0, 0, 2), seasonal_pdq=(1, 0, 2, 12)
# Complete for 25/288 MAE=0.08431988610901898, pdq=(0, 0, 2), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 26/288 MAE=0.05409717628174166, pdq=(0, 0, 2), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 27/288 MAE=0.05808445092663186, pdq=(0, 0, 2), seasonal_pdq=(2, 0, 2, 12)
# Complete for 28/288 MAE=0.7209836871790888, pdq=(0, 0, 3), seasonal_pdq=(0, 0, 0, 12)
# Complete for 29/288 MAE=0.48402498087226364, pdq=(0, 0, 3), seasonal_pdq=(0, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 30/288 MAE=0.3611123019559459, pdq=(0, 0, 3), seasonal_pdq=(0, 0, 2, 12)
# Complete for 31/288 MAE=0.0704833982088189, pdq=(0, 0, 3), seasonal_pdq=(1, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 32/288 MAE=0.04739677679183656, pdq=(0, 0, 3), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 33/288 MAE=0.07532933470615372, pdq=(0, 0, 3), seasonal_pdq=(1, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 34/288 MAE=0.08446587385830218, pdq=(0, 0, 3), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 35/288 MAE=0.08681793845769692, pdq=(0, 0, 3), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 36/288 MAE=0.04846271380954182, pdq=(0, 0, 3), seasonal_pdq=(2, 0, 2, 12)
# Complete for 37/288 MAE=0.05732171054221541, pdq=(0, 1, 0), seasonal_pdq=(0, 0, 0, 12)
# Complete for 38/288 MAE=0.057120635730048545, pdq=(0, 1, 0), seasonal_pdq=(0, 0, 1, 12)
# Complete for
 2), seasonal_pdq=(0, 0, 0, 12)
# Complete for 128/288 MAE=0.05642003281673341, pdq=(1, 1, 2), seasonal_pdq=(0, 0, 1, 12)
# Complete for 129/288 MAE=0.05443305877343593, pdq=(1, 1, 2), seasonal_pdq=(0, 0, 2, 12)
# Complete for 130/288 MAE=0.05713460755672307, pdq=(1, 1, 2), seasonal_pdq=(1, 0, 0, 12)
# Complete for 131/288 MAE=0.05605336209489675, pdq=(1, 1, 2), seasonal_pdq=(1, 0, 1, 12)
# Complete for 132/288 MAE=0.054451941237164736, pdq=(1, 1, 2), seasonal_pdq=(1, 0, 2, 12)
# Complete for 133/288 MAE=0.054542201488841785, pdq=(1, 1, 2), seasonal_pdq=(2, 0, 0, 12)
# Complete for 134/288 MAE=0.05447089440465114, pdq=(1, 1, 2), seasonal_pdq=(2, 0, 1, 12)
# Complete for 135/288 MAE=0.05443550009688367, pdq=(1, 1, 2), seasonal_pdq=(2, 0, 2, 12)
# Complete for 136/288 MAE=0.055175992035275824, pdq=(1, 1, 3), seasonal_pdq=(0, 0, 0, 12)
# Complete for 137/288 MAE=0.05399005243903099, pdq=(1, 1, 3), seasonal_pdq=(0, 0, 1, 12)
# Complete for 138/288 MAE=0.054342691049730774, pdq=(1, 1, 3), seasonal_pdq=(0, 0, 2, 12)
# Complete for 139/288 MAE=0.05387109897257614, pdq=(1, 1, 3), seasonal_pdq=(1, 0, 0, 12)
# Complete for 140/288 MAE=0.053705021432077726, pdq=(1, 1, 3), seasonal_pdq=(1, 0, 1, 12)
# Complete for 141/288 MAE=0.05437932761030137, pdq=(1, 1, 3), seasonal_pdq=(1, 0, 2, 12)
# Complete for 142/288 MAE=0.05438172562969951, pdq=(1, 1, 3), seasonal_pdq=(2, 0, 0, 12)
# Complete for 143/288 MAE=0.05431745428536758, pdq=(1, 1, 3), seasonal_pdq=(2, 0, 1, 12)
# Complete for 144/288 MAE=0.054365924508350004, pdq=(1, 1, 3), seasonal_pdq=(2, 0, 2, 12)
# Complete for 145/288 MAE=0.04900252809788449, pdq=(2, 0, 0), seasonal_pdq=(0, 0, 0, 12)
# Complete for 146/288 MAE=0.048820617114518926, pdq=(2, 0, 0), seasonal_pdq=(0, 0, 1, 12)
# Complete for 147/288 MAE=0.047086619647243484, pdq=(2, 0, 0), seasonal_pdq=(0, 0, 2, 12)
# Complete for 148/288 MAE=0.04870672266240805, pdq=(2, 0, 0), seasonal_pdq=(1, 0, 0, 12)
# Complete for 149/288 MAE=0.0485557131631247, pdq=(2, 0, 0), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 150/288 MAE=0.046924646910326794, pdq=(2, 0, 0), seasonal_pdq=(1, 0, 2, 12)
# Complete for 151/288 MAE=0.04738107071943068, pdq=(2, 0, 0), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 152/288 MAE=0.046993618086894944, pdq=(2, 0, 0), seasonal_pdq=(2, 0, 1, 12)
# Complete for 153/288 MAE=0.046837087279587096, pdq=(2, 0, 0), seasonal_pdq=(2, 0, 2, 12)
# Complete for 154/288 MAE=0.04866200376840357, pdq=(2, 0, 1), seasonal_pdq=(0, 0, 0, 12)
# Complete for 155/288 MAE=0.048276301969953445, pdq=(2, 0, 1), seasonal_pdq=(0, 0, 1, 12)
# Complete for 156/288 MAE=0.046710946968001134, pdq=(2, 0, 1), seasonal_pdq=(0, 0, 2, 12)
# Complete for 157/288 MAE=0.04814589482850054, pdq=(2, 0, 1), seasonal_pdq=(1, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 158/288 MAE=0.047228163455835005, pdq=(2, 0, 1), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 159/288 MAE=0.04650336314312622, pdq=(2, 0, 1), seasonal_pdq=(1, 0, 2, 12)
# Complete for 160/288 MAE=0.04692961273451066, pdq=(2, 0, 1), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 161/288 MAE=0.04660570817246152, pdq=(2, 0, 1), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 162/288 MAE=0.04696935207842017, pdq=(2, 0, 1), seasonal_pdq=(2, 0, 2, 12)
# Complete for 163/288 MAE=0.04815134412962388, pdq=(2, 0, 2), seasonal_pdq=(0, 0, 0, 12)
# Complete for 164/288 MAE=0.048120510694631136, pdq=(2, 0, 2), seasonal_pdq=(0, 0, 1, 12)
# Complete for 165/288 MAE=0.04689928845149476, pdq=(2, 0, 2), seasonal_pdq=(0, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 166/288 MAE=0.048060339522594676, pdq=(2, 0, 2), seasonal_pdq=(1, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 167/288 MAE=0.047832669444038696, pdq=(2, 0, 2), seasonal_pdq=(1, 0, 1, 12)
# Complete for 168/288 MAE=0.04687642768845545, pdq=(2, 0, 2), seasonal_pdq=(1, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 169/288 MAE=0.0469670888889805, pdq=(2, 0, 2), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 170/288 MAE=0.0467820452876474, pdq=(2, 0, 2), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 171/288 MAE=0.04692667392045973, pdq=(2, 0, 2), seasonal_pdq=(2, 0, 2, 12)
# Complete for 172/288 MAE=0.04776100026201141, pdq=(2, 0, 3), seasonal_pdq=(0, 0, 0, 12)
# Complete for 173/288 MAE=0.04774815696782286, pdq=(2, 0, 3), seasonal_pdq=(0, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 174/288 MAE=0.046842942066390884, pdq=(2, 0, 3), seasonal_pdq=(0, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 175/288 MAE=0.047720684372235, pdq=(2, 0, 3), seasonal_pdq=(1, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 176/288 MAE=0.04842948709630876, pdq=(2, 0, 3), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 177/288 MAE=0.04660971986237041, pdq=(2, 0, 3), seasonal_pdq=(1, 0, 2, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 178/288 MAE=0.04661295579776947, pdq=(2, 0, 3), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 179/288 MAE=0.046468530370994195, pdq=(2, 0, 3), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 180/288 MAE=0.04675969071977552, pdq=(2, 0, 3), seasonal_pdq=(2, 0, 2, 12)
# Complete for 181/288 MAE=0.057849635500839026, pdq=(2, 1, 0), seasonal_pdq=(0, 0, 0, 12)
# Complete for 182/288 MAE=0.05705013689844721, pdq=(2, 1, 0), seasonal_pdq=(0, 0, 1, 12)
# Complete for 183/288 MAE=0.0549978085129386, pdq=(2, 1, 0), seasonal_pdq=(0, 0, 2, 12)
# Complete for 184/288 MAE=0.056859376481341005, pdq=(2, 1, 0), seasonal_pdq=(1, 0, 0, 12)
# Complete for 185/288 MAE=0.05652958356716725, pdq=(2, 1, 0), seasonal_pdq=(1, 0, 1, 12)
# Complete for 186/288 MAE=0.05501828927330254, pdq=(2, 1, 0), seasonal_pdq=(1, 0, 2, 12)
# Complete for 187/288 MAE=0.055063612837472915, pdq=(2, 1, 0), seasonal_pdq=(2, 0, 0, 12)
# Complete for 188/288 MAE=0.05510027646870012, pdq=(2, 1, 0), seasonal_pdq=(2, 0, 1, 12)
# Complete for 189/288 MAE=0.05508896573417738, pdq=(2, 1, 0), seasonal_pdq=(2, 0, 2, 12)
# Complete for 190/288 MAE=0.057104540446239554, pdq=(2, 1, 1), seasonal_pdq=(0, 0, 0, 12)
# Complete for 191/288 MAE=0.05638519319843744, pdq=(2, 1, 1), seasonal_pdq=(0, 0, 1, 12)
# Complete for 192/288 MAE=0.05437917474136702, pdq=(2, 1, 1), seasonal_pdq=(0, 0, 2, 12)
# Complete for 193/288 MAE=0.05655190249197126, pdq=(2, 1, 1), seasonal_pdq=(1, 0, 0, 12)
# Complete for 194/288 MAE=0.05637288868726665, pdq=(2, 1, 1), seasonal_pdq=(1, 0, 1, 12)
# Complete for 195/288 MAE=0.05438845322448089, pdq=(2, 1, 1), seasonal_pdq=(1, 0, 2, 12)
# Complete for 196/288 MAE=0.05460100080155846, pdq=(2, 1, 1), seasonal_pdq=(2, 0, 0, 12)
# Complete for 197/288 MAE=0.054524334455106425, pdq=(2, 1, 1), seasonal_pdq=(2, 0, 1, 12)
# Complete for 198/288 MAE=0.05438678615004242, pdq=(2, 1, 1), seasonal_pdq=(2, 0, 2, 12)
# Complete for 199/288 MAE=0.057157352218448525, pdq=(2, 1, 2), seasonal_pdq=(0, 0, 0, 12)
# Complete for 200/288 MAE=0.056438444998101966, pdq=(2, 1, 2), seasonal_pdq=(0, 0, 1, 12)
# Complete for 201/288 MAE=0.05450932426662014, pdq=(2, 1, 2), seasonal_pdq=(0, 0, 2, 12)
# Complete for 202/288 MAE=0.05623088246616542, pdq=(2, 1, 2), seasonal_pdq=(1, 0, 0, 12)
# Complete for 203/288 MAE=0.056069615098650626, pdq=(2, 1, 2), seasonal_pdq=(1, 0, 1, 12)
# Complete for 204/288 MAE=0.054529390458509706, pdq=(2, 1, 2), seasonal_pdq=(1, 0, 2, 12)
# Complete for 205/288 MAE=0.05450152818070752, pdq=(2, 1, 2), seasonal_pdq=(2, 0, 0, 12)
# Complete for 206/288 MAE=0.05443042243650816, pdq=(2, 1, 2), seasonal_pdq=(2, 0, 1, 12)
# Complete for 207/288 MAE=0.05462802796789993, pdq=(2, 1, 2), seasonal_pdq=(2, 0, 2, 12)
# Complete for 208/288 MAE=0.05547096915055164, pdq=(2, 1, 3), seasonal_pdq=(0, 0, 0, 12)
# Complete for 209/288 MAE=0.05456998078280748, pdq=(2, 1, 3), seasonal_pdq=(0, 0, 1, 12)
# Complete for 210/288 MAE=0.05307592780715493, pdq=(2, 1, 3), seasonal_pdq=(0, 0, 2, 12)
# Complete for 211/288 MAE=0.0545077688075952, pdq=(2, 1, 3), seasonal_pdq=(1, 0, 0, 12)
# Complete for 212/288 MAE=0.05428128541199969, pdq=(2, 1, 3), seasonal_pdq=(1, 0, 1, 12)
# Complete for 213/288 MAE=0.053118925860773346, pdq=(2, 1, 3), seasonal_pdq=(1, 0, 2, 12)
# Complete for 214/288 MAE=0.053159495024953186, pdq=(2, 1, 3), seasonal_pdq=(2, 0, 0, 12)
# Complete for 215/288 MAE=0.05317970731984554, pdq=(2, 1, 3), seasonal_pdq=(2, 0, 1, 12)
# Complete for 216/288 MAE=0.05309645949369748, pdq=(2, 1, 3), seasonal_pdq=(2, 0, 2, 12)
# Complete for
# Complete for 256/288 MAE=0.05498394320313706, pdq=(3, 1, 0), seasonal_pdq=(1, 0, 0, 12)
# Complete for 257/288 MAE=0.054821731420111465, pdq=(3, 1, 0), seasonal_pdq=(1, 0, 1, 12)
# Complete for 258/288 MAE=0.05336495466428622, pdq=(3, 1, 0), seasonal_pdq=(1, 0, 2, 12)
# Complete for 259/288 MAE=0.05342648736989486, pdq=(3, 1, 0), seasonal_pdq=(2, 0, 0, 12)
# Complete for 260/288 MAE=0.053435353628104365, pdq=(3, 1, 0), seasonal_pdq=(2, 0, 1, 12)
# Complete for 261/288 MAE=0.053421118592682205, pdq=(3, 1, 0), seasonal_pdq=(2, 0, 2, 12)
# Complete for 262/288 MAE=0.057099368557729104, pdq=(3, 1, 1), seasonal_pdq=(0, 0, 0, 12)
# Complete for 263/288 MAE=0.05640088298980525, pdq=(3, 1, 1), seasonal_pdq=(0, 0, 1, 12)
# Complete for 264/288 MAE=0.05437763841357491, pdq=(3, 1, 1), seasonal_pdq=(0, 0, 2, 12)
# Complete for 265/288 MAE=0.05625820710985777, pdq=(3, 1, 1), seasonal_pdq=(1, 0, 0, 12)
# Complete for 266/288 MAE=0.05602068173229308, pdq=(3, 1, 1), seasonal_pdq=(1, 0, 1, 12)
# Complete for 267/288 MAE=0.054387447187961076, pdq=(3, 1, 1), seasonal_pdq=(1, 0, 2, 12)
# Complete for 268/288 MAE=0.05448689252227174, pdq=(3, 1, 1), seasonal_pdq=(2, 0, 0, 12)
# Complete for 269/288 MAE=0.05444311399655671, pdq=(3, 1, 1), seasonal_pdq=(2, 0, 1, 12)
# Complete for 270/288 MAE=0.054404994874213665, pdq=(3, 1, 1), seasonal_pdq=(2, 0, 2, 12)
# Complete for 271/288 MAE=0.05658356333241971, pdq=(3, 1, 2), seasonal_pdq=(0, 0, 0, 12)
# Complete for 272/288 MAE=0.05528308047209865, pdq=(3, 1, 2), seasonal_pdq=(0, 0, 1, 12)
# Complete for 273/288 MAE=0.05340631462287407, pdq=(3, 1, 2), seasonal_pdq=(0, 0, 2, 12)
# Complete for 274/288 MAE=0.05553210161461939, pdq=(3, 1, 2), seasonal_pdq=(1, 0, 0, 12)
# Complete for 275/288 MAE=0.055281989551450784, pdq=(3, 1, 2), seasonal_pdq=(1, 0, 1, 12)
# Complete for 276/288 MAE=0.05344726664611229, pdq=(3, 1, 2), seasonal_pdq=(1, 0, 2, 12)
# Complete for 277/288 MAE=0.05358992241189889, pdq=(3, 1, 2), seasonal_pdq=(2, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 278/288 MAE=0.053598731948650204, pdq=(3, 1, 2), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 279/288 MAE=0.05344621526016737, pdq=(3, 1, 2), seasonal_pdq=(2, 0, 2, 12)
# Complete for 280/288 MAE=0.056531469072363914, pdq=(3, 1, 3), seasonal_pdq=(0, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 281/288 MAE=0.06507087172052113, pdq=(3, 1, 3), seasonal_pdq=(0, 0, 1, 12)
# Complete for 282/288 MAE=0.062836273435947, pdq=(3, 1, 3), seasonal_pdq=(0, 0, 2, 12)
# Complete for 283/288 MAE=0.05529709304954742, pdq=(3, 1, 3), seasonal_pdq=(1, 0, 0, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 284/288 MAE=0.06464973408815182, pdq=(3, 1, 3), seasonal_pdq=(1, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 285/288 MAE=0.06831600546216825, pdq=(3, 1, 3), seasonal_pdq=(1, 0, 2, 12)
# Complete for 286/288 MAE=0.05290845472677036, pdq=(3, 1, 3), seasonal_pdq=(2, 0, 0, 12)
# Complete for 287/288 MAE=0.05279917108141718, pdq=(3, 1, 3), seasonal_pdq=(2, 0, 1, 12)
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Complete for 288/288 MAE=0.06261994825549548, pdq=(3, 1, 3), seasonal_pdq=(2, 0, 2, 12)

# %%
best_results
# Out:
# 0.04632383531167975

# %%
best_pdq
# Out:
# (3, 0, 1)

# %%
best_seasonal_pdq
# Out:
# (2, 0, 1, 12)

# %%
model1 = sm.tsa.statespace.SARIMAX(train, order = (3,0,1), seasonal_order=(2,0,1,12),
                                enforce_stationary = False,
                                enforce_invertibility = False).fit()
# Out:
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\ABHAY\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
ftest=model1.forecast(12)
ftest
# Out:
# 2020-01-05    67.909225
# 2020-01-12    67.830140
# 2020-01-19    67.958636
# 2020-01-26    67.785656
# 2020-02-02    67.768623
# 2020-02-09    67.692267
# 2020-02-16    67.551460
# 2020-02-23    67.780087
# 2020-03-01    67.743182
# 2020-03-08    67.706364
# 2020-03-15    67.743091
# 2020-03-22    67.723413
# Freq: W-SUN, Name: predicted_mean, dtype: float64

# %%
model1.forecast(12).plot()
# Out:
# <AxesSubplot:>

# %%
train.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Plot the forecast along with the confidence band

axis = train.plot(label = 'Observed', figsize = (15,6))
ftest.plot(ax=axis, label = 'Forecast', alpha = 0.7)

axis.set_xlabel('Years')
axis.set_ylabel('High')
plt.legend(loc='best')
plt.show()

# %%
from pmdarima.arima import auto_arima

stepwise_model = auto_arima(Yt_data1,
                           start_p=1, start_q=1,
                           max_p=5, max_q=4, m=12,
                           start_P=1, max_P=3, seasonal=True,
                           d=1, D=1, max_d = 3, max_D=3, trace=True, 
                            error_action='ignore',
                            suppress_warnings=True,
                            stepwise=True, scoring='mae')
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=2.12 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=2729.224, Time=0.12 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=2542.011, Time=0.35 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=1.02 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=2730.181, Time=0.11 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=2478.437, Time=0.59 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=2451.351, Time=1.16 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=inf, Time=4.71 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=2.13 sec
#  ARIMA(0,1,0)(3,1,0)[12]             : AIC=2461.550, Time=0.82 sec
#  ARIMA(2,1,0)(3,1,0)[12]             : AIC=2453.202, Time=1.46 sec
#  ARIMA(1,1,1)(3,1,0)[12]             : AIC=2453.007, Time=7.33 sec
#  ARIMA(0,1,1)(3,1,0)[12]             : AIC=2451.064, Time=1.79 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=2477.160, Time=0.90 sec
#  ARIMA(0,1,1)(3,1,1)[12]             : AIC=inf, Time=5.83 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=inf, Time=3.84 sec
#  ARIMA(0,1,2)(3,1,0)[12]             : AIC=2453.038, Time=2.31 sec
#  ARIMA(1,1,2)(3,1,0)[12]             : AIC=inf, Time=9.80 sec
#  ARIMA(0,1,1)(3,1,0)[12] intercept   : AIC=2452.795, Time=4.05 sec
#
# Best model:  ARIMA(0,1,1)(3,1,0)[12]
# Total fit time: 50.507 seconds
# 2451.0637929761983
